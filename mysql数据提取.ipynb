# %%
import pymysql
import pandas as pd
from sqlalchemy import create_engine
import urllib.parse

"""
通过SSH跳板连接MySQL数据库。
"""


def connect_sql_execute(query_str, method='pandas'):
    sql_hostname = "172.18.54.40"
    sql_username = "developer"
    sql_password = "Hq)%33K7HpJGHaavV"
    sql_port = 6447
    db_name = "megaview_db"
    # 这里由于存在)%等特殊符号，在url中显示不同，所以需要处理才能正确连接
    sql_password = urllib.parse.quote_plus(sql_password)

    engine = create_engine(f"mysql+pymysql://{sql_username}:{sql_password}@{sql_hostname}:{sql_port}/{db_name}")

    if method == 'pandas':
        data = pd.read_sql_query(query_str, engine)
        engine.dispose()
    return data

# %%
import pymysql

connection = pymysql.connect(host='172.18.54.40', user='developer', password='Hq)%33K7HpJGHaavV', db='megaview_db', connect_timeout=10)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[4], line 3
#       1 import pymysql
# ----> 3 connection = pymysql.connect(host='172.18.54.40', user='developer', password='Hq)%33K7HpJGHaavV', db='megaview_db', connect_timeout=10)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pymysql\connections.py:358, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, collation, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     356     self._sock = None
#     357 else:
# ...

# %%
query = f'show create table conversation'
conversation_res = connect_sql_execute(query)
print(conversation_res['Create Table'].tolist()[0])
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File D:\anaconda\Lib\site-packages\sqlalchemy\engine\base.py:3280, in Engine._wrap_pool_connect(self, fn, connection)
#    3279 try:
# -> 3280     return fn()
#    3281 except dialect.dbapi.Error as e:
#
# File D:\anaconda\Lib\site-packages\sqlalchemy\pool\base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File D:\anaconda\Lib\site-packages\sqlalchemy\pool\base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# --> 868     fairy = _ConnectionRecord.checkout(pool)
#     870     fairy._pool = pool
#
# ...
